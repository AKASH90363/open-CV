# %%
#read and display img
#covert image into greyscale
#resize an image
#draw shapes in img

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

image = cv2.imread('/content/1969.jpg')
kernal_size = 13; sigma=3.5
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=299x168>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image = cv2.imread('/content/1969.jpg')
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image, cmap='gray')
plt.show()

height,width,channels = image.shape
print(height,width,channels)
image_size=image.size
print(f"Total Pixels:{image.size}")
# Out:
# 168 299 3
# Total Pixels:150696

# %%
from google.colab.patches import cv2_imshow
import cv2
image = cv2.imread("/content/1969.jpg")
cv2.circle(image,(100,112),30,(0,30,0),3)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=299x168>

# %%
from google.colab.patches import cv2_imshow
import cv2
image = cv2.imread("/content/1969.jpg")
resized_image = cv2.resize(image,(200,200))
cv2_imshow(resized_image)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>
